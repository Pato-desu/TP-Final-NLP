# %% [markdown]
# # Procesamiento del Lenguaje Natural
#
# # Trabajo Práctico Final
#
# # Vercesi Patricio

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# ## Orden a programarlo
#
# 1. sacar los import e install innecesarios

# %% [markdown]
# ## Introducción

# %% [markdown]
# ## Importación de librerías

# %%
"""
# !apt install python3.10-venv
# !python -m venv chatbot
import sys
sys.path.insert(0, 'chatbot/lib/python3.7/site-packages')
"""
# Out:
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# ^C

# %%
#Importación de librerias
#from google.colab import files, drive
import pandas as pd
import openpyxl
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

## Langchain

#import gdown

# %%
#!pip install -r https://drive.google.com/file/d/1MiYX8COfeWA1AUqwUUxIJ2YsLPZzfwU6/view?usp=sharing
#!gdown 1MiYX8COfeWA1AUqwUUxIJ2YsLPZzfwU6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1MiYX8COfeWA1AUqwUUxIJ2YsLPZzfwU6
# To: /content/requirements.txt
# 100% 10.6k/10.6k [00:00<00:00, 35.1MB/s]

# %%
# !pip install absl-py==2.1.0
# !pip install aiofiles==23.2.1
# !pip install aiogram==3.3.0
# !pip install aiohttp==3.9.3
# !pip install aiosignal==1.3.1
# !pip install altair==5.2.0
# !pip install annotated-types==0.6.0
# !pip install anyio==4.2.0
# !pip install asgiref==3.7.2
# !pip install astunparse==1.6.3
# !pip install async-timeout==4.0.3
# !pip install attrs==23.2.0
# !pip install Babel==2.9.1
# !pip install backoff==2.2.1
# !pip install bcrypt==4.1.2
# !pip install beautifulsoup4==4.12.2
# !pip install blinker==1.7.0
# !pip install blis==0.7.11
# !pip install botasaurus==3.2.3
# !pip install botasaurus-proxy-authentication==1.0.1
# !pip install bs4==0.0.1
# !pip install build==1.0.3
# !pip install cachetools==5.3.2
# !pip install casefy==0.1.7
# !pip install catalogue==2.0.10
# !pip install certifi==2023.11.17
# !pip install cffi==1.16.0
# !pip install charset-normalizer==3.3.2
# !pip install chroma-hnswlib==0.7.3
# !pip install chromadb==0.4.22
# !pip install chromedriver-autoinstaller==0.6.3
# !pip install click==8.1.7
# !pip install cloudpathlib==0.16.0
# !pip install cloudscraper==1.2.71
# !pip install colorama==0.4.6
# !pip install coloredlogs==15.0.1
# !pip install confection==0.1.4
# !pip install contourpy==1.2.0
# !pip install cycler==0.12.1
# !pip install cymem==2.0.8
# !pip install dataclasses-json==0.6.3
# !pip install dateutils==0.6.12
# !pip install Deprecated==1.2.14
# !pip install distro==1.9.0
# !pip install document-utils==1.8.1
# !pip install docutils==0.20.1
# !pip install es-core-news-sm @ https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl#sha256=61e6e5530941f5880166855f09f60d7e6ba79ec1e8e45f96244bdb1eb169eb1d
# !pip install exceptiongroup==1.2.0
# !pip install fastapi==0.109.0
# !pip install filelock==3.9.0
# !pip install flatbuffers==23.5.26
# !pip install fonttools==4.47.2
# !pip install frozenlist==1.4.1
# !pip install fsspec==2023.12.2
# !pip install gast==0.4.0
# !pip install geonamescache==2.0.0
# !pip install gitdb==4.0.11
# !pip install GitPython==3.1.41
# !pip install google-auth==2.27.0
# !pip install google-auth-oauthlib==0.4.6
# !pip install google-pasta==0.2.0
# !pip install googleapis-common-protos==1.62.0
# !pip install gpt-index==0.8.42
# !pip install greenlet==3.0.3
# !pip install grpcio==1.60.0
# !pip install h11==0.14.0
# !pip install h5py==3.10.0
# !pip install httpcore==1.0.2
# !pip install httptools==0.6.1
# !pip install httpx==0.25.2
# !pip install huggingface-hub==0.17.3
# !pip install humanfriendly==10.0
# !pip install idna==3.6
# !pip install importlib-metadata==6.11.0
# !pip install importlib-resources==6.1.1
# !pip install isodate==0.6.1
# !pip install jaraco.classes==3.3.0
# !pip install javascript==1!1.1.2
# !pip install Jinja2==3.1.2
# !pip install joblib==1.3.2
# !pip install jsonpatch==1.33
# !pip install jsonpointer==2.4
# !pip install jsonschema==4.21.1
# !pip install jsonschema-specifications==2023.12.1
# !pip install keras==2.10.0
# !pip install Keras-Preprocessing==1.1.2
# !pip install keyring==24.3.0
# !pip install kiwisolver==1.4.5
# !pip install kubernetes==29.0.0
# !pip install langchain==0.1.0
# !pip install langchain-community==0.0.11
# !pip install langchain-core==0.1.10
# !pip install langcodes==3.3.0
# !pip install langsmith==0.0.80
# !pip install libclang==16.0.6
# !pip install llama-index==0.9.38
# !pip install lxml==5.1.0
# !pip install magic-filter==1.0.12
# !pip install Markdown==3.5.2
# !pip install markdown-it-py==3.0.0
# !pip install MarkupSafe==2.1.3
# !pip install marshmallow==3.20.2
# !pip install matplotlib==3.8.2
# !pip install mdurl==0.1.2
# !pip install mmh3==4.1.0
# !pip install monotonic==1.6
# !pip install more-itertools==10.2.0
# !pip install mpmath==1.3.0
# !pip install multidict==6.0.4
# !pip install murmurhash==1.0.10
# !pip install mypy-extensions==1.0.0
# !pip install nest-asyncio==1.5.8
# !pip install networkx==3.0
# !pip install nh3==0.2.15
# !pip install nltk==3.8.1
# !pip install numpy==1.26.3
# !pip install oauthlib==3.2.2
# !pip install onnxruntime==1.16.3
# !pip install openai==1.10.0
# !pip install opentelemetry-api==1.22.0
# !pip install opentelemetry-exporter-otlp-proto-common==1.22.0
# !pip install opentelemetry-exporter-otlp-proto-grpc==1.22.0
# !pip install opentelemetry-instrumentation==0.43b0
# !pip install opentelemetry-instrumentation-asgi==0.43b0
# !pip install opentelemetry-instrumentation-fastapi==0.43b0
# !pip install opentelemetry-proto==1.22.0
# !pip install opentelemetry-sdk==1.22.0
# !pip install opentelemetry-semantic-conventions==0.43b0
# !pip install opentelemetry-util-http==0.43b0
# !pip install opt-einsum==3.3.0
# !pip install outcome==1.3.0.post0
# !pip install outscraper==5.0.0
# !pip install overrides==7.6.0
# !pip install packaging==23.2
# !pip install pandas==2.1.4
# !pip install Pillow==9.3.0
# !pip install pkginfo==1.9.6
# !pip install posthog==3.3.2
# !pip install preshed==3.0.9
# !pip install protobuf==3.19.6
# !pip install psutil==5.9.8
# !pip install pulsar-client==3.4.0
# !pip install pyarrow==15.0.0
# !pip install pyasn1==0.5.1
# !pip install pyasn1-modules==0.3.0
# !pip install pycparser==2.21
# !pip install pydantic==2.5.3
# !pip install pydantic_core==2.14.6
# !pip install pydeck==0.8.1b0
# !pip install Pygments==2.17.2
# !pip install pyparsing==3.1.1
# !pip install pypdf==3.17.4
# !pip install PyPDF2==3.0.1
# !pip install PyPika==0.48.9
# !pip install pyproject_hooks==1.0.0
# !pip install pyreadline3==3.4.1
# !pip install PySocks==1.7.1
# !pip install pyTelegramBotAPI==4.14.1
# !pip install python-dateutil==2.8.2
# !pip install python-decouple==3.8
# !pip install python-dotenv==1.0.1
# !pip install python-telegram-bot==20.7
# !pip install pytz==2023.3.post1
# !pip install pywin32-ctypes==0.2.2
# !pip install PyYAML==6.0.1
# !pip install qwikidata==0.4.2
# !pip install rdflib==7.0.0
# !pip install readme-renderer==42.0
# !pip install referencing==0.32.1
# !pip install regex==2023.12.25
# !pip install requests==2.31.0
# !pip install requests-oauthlib==1.3.1
# !pip install requests-toolbelt==1.0.0
# !pip install rfc3986==2.0.0
# !pip install rich==13.7.0
# !pip install rpds-py==0.17.1
# !pip install rsa==4.9
# !pip install safetensors==0.4.1
# !pip install scikit-learn==1.3.2
# !pip install scipy==1.11.4
# !pip install selenium==4.5.0
# !pip install sentence-transformers==2.2.2
# !pip install sentencepiece==0.1.99
# !pip install six==1.16.0
# !pip install smart-open==6.4.0
# !pip install smmap==5.0.1
# !pip install sniffio==1.3.0
# !pip install sortedcontainers==2.4.0
# !pip install soupsieve==2.5
# !pip install spacy==3.7.2
# !pip install spacy-legacy==3.0.12
# !pip install spacy-loggers==1.0.5
# !pip install SPARQLWrapper==2.0.0
# !pip install SQLAlchemy==2.0.25
# !pip install srsly==2.4.8
# !pip install starlette==0.35.1
# !pip install streamlit==1.30.0
# !pip install sympy==1.12
# !pip install telebot==0.0.5
# !pip install tenacity==8.2.3
# !pip install tensorboard==2.10.1
# !pip install tensorboard-data-server==0.6.1
# !pip install tensorboard-plugin-wit==1.8.1
# !pip install tensorflow==2.10.1
# !pip install tensorflow-estimator==2.10.0
# !pip install tensorflow-hub==0.16.0
# !pip install tensorflow-io-gcs-filesystem==0.31.0
# !pip install tensorflow-text==2.10.0
# !pip install termcolor==2.4.0
# !pip install textblob==0.17.1
# !pip install thinc==8.2.2
# !pip install threadpoolctl==3.2.0
# !pip install tika==2.6.0
# !pip install tiktoken==0.5.2
# !pip install tokenizers==0.14.1
# !pip install toml==0.10.2
# !pip install tomli==2.0.1
# !pip install toolz==0.12.1
# !pip install torch==2.1.2+cu118
# !pip install torchaudio==2.1.2+cu118
# !pip install torchvision==0.16.2+cu118
# !pip install tornado==6.2
# !pip install tqdm==4.66.1
# !pip install traitlets==5.3.0
# !pip install transformers==4.34.1
# !pip install trio==0.24.0
# !pip install trio-websocket==0.11.1
# !pip install twine==4.0.1
# !pip install typer==0.9.0
# !pip install typing==3.7.4.3
# !pip install typing-inspect==0.9.0
# !pip install typing_extensions==4.9.0
# !pip install tzdata==2023.3
# !pip install tzlocal==5.2
# !pip install Unidecode==1.3.8
# !pip install urllib3==1.26.9
# !pip install ushlex==0.99.1
# !pip install uvicorn==0.27.0
# !pip install validators==0.22.0
# !pip install vectorhub==1.8.3
# !pip install wasabi==1.1.2
# !pip install watchdog==3.0.0
# !pip install watchfiles==0.21.0
# !pip install wcwidth==0.2.5
# !pip install weasel==0.3.3
# !pip install webencodings==0.5.1
# !pip install websocket-client==1.3.2
# !pip install websockets==12.0
# !pip install Werkzeug==2.2.2
# !pip install widgetsnbextension==4.0.9
# !pip install wordcloud==1.9.2
# !pip install wrapt==1.14.1
# !pip install wsproto==1.2.0
# !pip install xyzservices==2023.7.0
# !pip install yarg==0.1.9
# !pip install yarl==1.9.4
# !pip install zipp==3.8.0
# Out:
# ...
# ERROR: Invalid requirement: '@'
# ...
# ...
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 3.19.6 which is incompatible.
# ...
#    ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#    ---------------------------------------- 82.0/82.0 kB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: watchdog
#     Found existing installation: watchdog 4.0.0
#     Uninstalling watchdog-4.0.0:
#       Successfully uninstalled watchdog-4.0.0
# ...
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
# ...
#    ---------------------------------------- 0.0/49.8 kB ? eta -:--:--
#    -------------------------------- ------- 41.0/49.8 kB 991.0 kB/s eta 0:00:01
# ...

# %%
#!pip install -r requirements.txt

# %%
#!pip install llama-index==0.9.38 -q
#!pip install llama-index-embeddings-huggingface==0.1.1 sentence-transformers==2.3.1 pypdf==4.0.1 langchain==0.1.7 python-decouple==3.8 llama-index-readers-file==0.1.3 -q

# %%
"""
# %%writefile /usr/local/lib/python3.10/dist-packages/openai/_utils/_streams.py
from typing import Any
from typing_extensions import AsyncIterator
from typing import Iterator # import Iterator from the correct library

def consume_sync_iterator(iterator: Iterator[Any]) -> None:
    for _ in iterator:
        ...

async def consume_async_iterator(iterator: AsyncIterator[Any]) -> None:
    async for _ in iterator:
        ...
"""
# Out:
# Writing /usr/local/lib/python3.10/dist-packages/openai/_utils/_streams.py
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_ipython().run_cell_magic('writefile', '/usr/local/lib/python3.10/dist-packages/openai/_utils/_streams.py', 'from typing import Any\nfrom typing_extensions import AsyncIterator\nfrom typing import Iterator # import Iterator from the correct library\n\ndef consume_sync_iterator(iterator: Iterator[Any]) -> None:\n    for _ in iterator:\n        ...\n\nasync def consume_async_iterator(iterator: AsyncIterator[Any]) -> None:\n    async for _ in iterator:\n        ...\n')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# ...

# %%
#!pip install llama_index.core

# %%
"""
# !pip uninstall llama-index
# !pip uninstall llama-index-legacy
# !pip uninstall llama-index-agent-openai
# !pip uninstall llama-index-core
# !pip uninstall llama-index-embeddings-adapter
# !pip uninstall llama-index-embeddings-openai
# !pip uninstall llama-index-finetuning
# !pip uninstall llama-index-llms-gradient
# !pip uninstall llama-index-llms-openai
# !pip uninstall llama-index-multi-modal-llms-openai
# !pip uninstall llama-index-postprocessor-cohere-rerank
# !pip uninstall llama-index-program-openai
# !pip uninstall llama-index-question-gen-openai
# !pip uninstall llama-index-readers-file

# !pip install llama-index
"""
# Out:
# '\n!pip uninstall llama-index\n!pip uninstall llama-index-legacy\n!pip uninstall llama-index-agent-openai\n!pip uninstall llama-index-core\n!pip uninstall llama-index-embeddings-adapter\n!pip uninstall llama-index-embeddings-openai\n!pip uninstall llama-index-finetuning\n!pip uninstall llama-index-llms-gradient\n!pip uninstall llama-index-llms-openai\n!pip uninstall llama-index-multi-modal-llms-openai\n!pip uninstall llama-index-postprocessor-cohere-rerank\n!pip uninstall llama-index-program-openai\n!pip uninstall llama-index-question-gen-openai\n!pip uninstall llama-index-readers-file\n\n!pip install llama-index\n'

# %%
#!pip install llama-index==0.9.38 -q

# %%
#!pip install langchain_community==0.0.11

# %%
# !pip install openai==1.10.0

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#from llama_index import VectorStoreIndex
from llama_index import VectorStoreIndex, SimpleDirectoryReader
from jinja2 import Template
import requests
from decouple import config
from llama_index import Settings
#from google.colab import userdata

#from llama_index.embeddings import LangchainEmbedding
#from llama_index import ServiceContext
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 4
#       2 from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#       3 #from llama_index import VectorStoreIndex
# ----> 4 from llama_index import VectorStoreIndex, SimpleDirectoryReader
#       5 from jinja2 import Template
#       6 import requests
#
# File c:\Users\Patricio\AppData\Local\Programs\Python\Python311\Lib\site-packages\llama_index\__init__.py:21
#      18 from llama_index.embeddings.openai import OpenAIEmbedding
#      20 # structured
# ---> 21 from llama_index.indices.common.struct_store.base import SQLDocumentContextBuilder
#      23 # for composability
#      24 from llama_index.indices.composability.graph import ComposableGraph
#
# File c:\Users\Patricio\AppData\Local\Programs\Python\Python311\Lib\site-packages\llama_index\indices\__init__.py:4
# ...

# %% [markdown]
# ## Importación de datos

# %%
# Link con archivos
data_url = 'https://drive.google.com/drive/folders/1ggyZinCPcA5o9bm4Fh8LO_Cjw1y8YvjS?usp=sharing'
# Descarga carpeta
gdown.download_folder(data_url, quiet=True, output='data')
file_path = 'data/'

# %% [markdown]
# ### Docx/ PDF

# %% [markdown]
# splitting??? langchain.recursivecharactertextsplitter?
#
# embedding (con OpenAI por ej)
#
# vectorizar (en chromaDB)

# %%
# !pip install PyPDF2 -q
import PyPDF2

# %%
# Open the PDF file
with open(file_path+'PDF/'+'art_of_game_design.pdf', 'rb') as file:
    # Create a PDF reader object
    pdf_reader = PyPDF2.PdfReader(file)

    # Read the text from the first few pages
    text = ''
    for page_num in range(5):  # Read the first 5 pages, for example
        page = pdf_reader.pages[page_num]
        text += page.extract_text()

print(text)

# %% [markdown]
# ### CSV

# %%
df = pd.read_csv(file_path+'CSVs/'+'consolas_mejor_vendidas.csv', encoding='latin1')
df

# %% [markdown]
# ### Base de datos de grafos

# %% [markdown]
# Bajé un CSV de la página https://query.wikidata.org que te deja hacer queries a Wikidata que es una base de datos de grafos online.
#
# Esta fue la query que hice:

# %%
"""
SELECT ?GameLabel (MIN(?Date) AS ?InitialReleaseDate) (GROUP_CONCAT(DISTINCT ?GenreLabel; separator=", ") AS ?Genres)
WHERE {
  # ?Game wdt:P178 wd:Q193559 ;
        wdt:P31 wd:Q7889 ;
        rdfs:label ?GameLabel ;
        wdt:P577 ?Date ;
        wdt:P136 ?Genre .
  # ?Genre rdfs:label ?GenreLabel .
  FILTER ((LANG(?GameLabel) = "en") && (LANG(?GenreLabel) = "en"))
}
GROUP BY ?GameLabel
"""

# %%
df = pd.read_csv(file_path+'CSVs/'+'valve_games_with_dates.csv', encoding='latin1')
df

# %% [markdown]
# ## Preparación de funciones y demás para usar la LLM

# %%
"""%%writefile /usr/local/lib/python3.10/dist-packages/ppocr/utils/utility.py
from typing import Any
from typing_extensions import AsyncIterator
from typing import Iterator # import Iterator from the correct library

def consume_sync_iterator(iterator: Iterator[Any]) -> None:
    for _ in iterator:
        ...

async def consume_async_iterator(iterator: AsyncIterator[Any]) -> None:
    async for _ in iterator:
        ...
"""

# %%
# Preparamos el retriever de documentos
# Construimos un índice de documentos a partir de los datos de la carpeta
reader = SimpleDirectoryReader("data")
documents = reader.load_data()

# Embedding de todos los documentos
embed_model = HuggingFaceEmbedding(model_name='sentence-transformers/distiluse-base-multilingual-cased-v2')
#embed_model = HuggingFaceEmbedding(model_name='HuggingFaceH4/zephyr-7b-beta')
"""
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
texts = text_splitter.split_documents(documents)

print(texts)
"""

# %%
"""
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
texts = text_splitter.split_documents(documents)

print(texts)
"""

# %%
#type(document[0])

# %%
#document[0]

# %%
#type(texts)

# %%
"""
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)
"""

# %%
#from langchain.vectorstores import Chroma
#vector_db = Chroma.from_documents(documents, embed_model)

vector_db = VectorStoreIndex.from_documents(documents, show_progress=True, embed_model=embed_model)

# Construimos un retriever a partir del índice, para realizar la búsqueda vectorial de documentos
retriever = vector_db.as_retriever(similarity_top_k=5) # devuelve el documento más relevante

# %%
# Todo el procesamiento para convertir a las prompts en lo que le queremos pasar a la LLM
def prompt_processing(queries, nodes_lists = False):
    # Añadimos el contexto de la pregunta
    contexted_queries = []

    for i in range(len(queries)):
        contexted_query = ''
        # si hay informacion contextual la agregamos
        if nodes_lists:
            # pasamos el contexto de nodos a string
            context = ''
            for node in nodes_lists[i]:
                context += f"{node.text}\n"
            # lo agregamos
            contexted_query += "La información contextual es:\n"
            contexted_query += "---------------------\n"
            contexted_query += f"{context}\n"
            contexted_query += "---------------------\n"
        # y en cualquier caso siempre lo contextuamos con el formato QA
        contexted_query += "Pregunta: \n"
        contexted_query += f"{queries[i]}\n"
        contexted_query += "Respuesta: \n"

        contexted_queries.append(contexted_query)

    # agregamos msjs del sistema
    messages_list = []

    if nodes_lists:
        msj_sistema = {
            "role": "system",
            "content": "Eres un asistente útil que siempre responde con respuestas veraces, útiles y usando el contexto que te brindan.",
        }
    else:
        msj_sistema = {
            "role": "system",
            "content": "Eres un asistente útil que siempre responde con respuestas veraces y útiles",
        }

    for contexted_query in contexted_queries:
        messages = [msj_sistema,
            {
                "role": "user",
                "content": contexted_query
            }
        ]

        messages_list.append(messages)

    # Conversión de mensajes del sistema o del usuario a formato Zephyr
    template_str = "{% for message in messages %}"
    template_str += "{% if message['role'] == 'user' %}"
    template_str += "<|user|>{{ message['content'] }}</s>\n"
    template_str += "{% elif message['role'] == 'assistant' %}"
    template_str += "<|assistant|>{{ message['content'] }}</s>\n"
    template_str += "{% elif message['role'] == 'system' %}"
    template_str += "<|system|>{{ message['content'] }}</s>\n"
    template_str += "{% else %}"
    template_str += "<|unknown|>{{ message['content'] }}</s>\n"
    template_str += "{% endif %}"
    template_str += "{% endfor %}"
    template_str += "{% if add_generation_prompt %}"
    template_str += "<|assistant|>\n"
    template_str += "{% endif %}"
    # Crear un objeto de plantilla con la cadena de plantilla
    template = Template(template_str)

    final_prompts = []

    for messages in messages_list:
        # Renderizar la plantilla con los mensajes proporcionados
        formatted_prompt = template.render(messages=messages, add_generation_prompt=True)
        final_prompts.append(formatted_prompt)

    return final_prompts

# %%
# Aquí hacemos la llamada al modelo
def generate_answers(prompts: str, max_new_tokens: int = 768) -> None:
    try:
        # URL de la API de Hugging Face para la generación de texto
        zephyr_api = "https://api-inference.huggingface.co/models/HuggingFaceH4/zephyr-7b-beta"

        answers = []

        for prompt in prompts:
            # Datos para enviar en la solicitud POST
            # Sobre los parámetros: https://huggingface.co/docs/transformers/main_classes/text_generation
            data = {
                "inputs": prompt,
                "parameters": {
                    "max_new_tokens": max_new_tokens,
                    "temperature": 0.1,
                    "top_k": 50,
                    "top_p": 0.95
                }
            }

            # Realizamos la solicitud POST a la LLM
            response = requests.post(zephyr_api, json=data)
            # Extraer respuesta
            answer = response.json()[0]["generated_text"][len(prompt):]
            answers.append(answer)

        return answers

    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def prompts2responses(queries, context = True):
    # contextos de las queries
    nodes_lists = []
    if context:
        for query in queries:
            nodes_lists.append(retriever.retrieve(query))

    # añadimos el contexto al prompt y lo procesamos
    final_prompts = prompt_processing(queries, nodes_lists)

    # obtenemos las respuestas
    answers = generate_answers(final_prompts)

    #imprimimos
    for i in range(len(queries)):
        print(
            "____________________________________________________________________\n\n"
            "# Pregunta:\n"
            f"{queries[i]}\n\n"
            "# Respuesta:\n"
            f"{answers[i]}\n\n"
        )
        if context:
            print(f"# Información sobre el documento usado:\n{nodes_lists[i][0]}\n")

# %%
default_queries = [
    '¿Cuáles son las 5 consolas mejor vendidas de la historia?',    #PS2, DS, Switch, Game Boy, PS
    '¿Qué año salió Half-Life 2: Lost Coast?',                      #2005
    '¿Cuántos capítulos tiene el libro "The Art of Game Design"?',  #33
]

# %% [markdown]
# ## LLM sin información contextual

# %%
prompts2responses(default_queries, context = False)

# %% [markdown]
# ## LLM con información contextual

# %%
prompts2responses(default_queries, context = True)

# %% [markdown]
# ## Testear con otros prompts

# %%
queries = [
    '¿De qué habla el libro "The Art of Game Design"?'
]

prompts2responses(queries, context = True)
